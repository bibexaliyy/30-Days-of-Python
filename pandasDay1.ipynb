# %% [markdown]
# <a href="https://colab.research.google.com/github/bibexaliyy/30-Days-of-Python/blob/main/pandasDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget "https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2024.zip"
# Out:
# --2025-12-05 05:32:53--  https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2024.zip
# Resolving survey.stackoverflow.co (survey.stackoverflow.co)... 3.33.186.135, 15.197.167.90
# Connecting to survey.stackoverflow.co (survey.stackoverflow.co)|3.33.186.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17703733 (17M) [application/zip]
# Saving to: ‘stack-overflow-developer-survey-2024.zip’
#
# stack-overflow-deve 100%[===================>]  16.88M  75.9MB/s    in 0.2s
#
# 2025-12-05 05:32:53 (75.9 MB/s) - ‘stack-overflow-developer-survey-2024.zip’ saved [17703733/17703733]

# %%
import zipfile

with zipfile.ZipFile('/content/stack-overflow-developer-survey-2024.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                              I am learning to code
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 65417       65425                     I am a developer by profession
# 65418       65426                     I am a developer by profession
# 65419       65427                              I am learning to code
# 65420       65428  I am not primarily a developer, but I write co...
# 65421       65429                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 65427       65428  I am not primarily a developer, but I write co...
# 65428       65429                     I am a developer by profession
# 65429       65430                              I am learning to code
# 65430       65431                              I am learning to code
# 65431       65432                     I am a developer by profession
# 65432       65433                     I am a developer by profession
# 65433       65434                     I am a developer by profession
# 65434       65435                     I am a developer by profession
# 65435       65436                     I am a developer by profession
# 65436       65437                        I code primarily as a hobby
#
#                    Age                                         Employment  \
# 65427  25-34 years old  Not employed, but looking for work;Employed, p...
# ...

# %%
schema_df=pd.read_csv("survey_results_schema.csv")

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %% [markdown]
# # Using Trsaditional python to store data without using pandas can be done in this way.This is done using lists and dictionaries

# %%
person = {"first":"Habiba",
          "last":"Isah",
          "email":"hisah075@gmail.com"}

# %%
people ={"first":["Habiba"],
         "Last":["Isah"],
         "email":["hisah075@gmail.com"]
         }

# %%
people ={"first":["Habiba","Hauwa","Khadija"],
         "last":["Isah","Bello","Saqiq"],
         "email":["hisah075@gmail.com","h02345@gmail.com","12356@yahoo.com"]}

# %%
people['email']
# Out:
# ['hisah075@gmail.com', 'h02345@gmail.com', '12356@yahoo.com']

# %%
df_people=pd.DataFrame(people)

# %%
df_people
# Out:
#      first   last               email
# 0   Habiba   Isah  hisah075@gmail.com
# 1    Hauwa  Bello    h02345@gmail.com
# 2  Khadija  Saqiq     12356@yahoo.com

# %%
df_people["email"]
# Out:
# 0    hisah075@gmail.com
# 1      h02345@gmail.com
# 2       12356@yahoo.com
# Name: email, dtype: object

# %%
type(df_people["email"])
# Out:
# pandas.core.series.Series
